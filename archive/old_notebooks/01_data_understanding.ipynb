# %% [markdown]
# # 01 Data Understanding
#
# Goal: load the official UCI Taiwan credit-card default dataset, verify the schema, and document the first data quality checks.

# %%
from pathlib import Path
import sys
import pandas as pd

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.append(str(PROJECT_ROOT / "src"))

from data_preprocessing import load_raw_dataset, data_quality_report, RAW_DATA_PATH

# %%
raw_df = load_raw_dataset(RAW_DATA_PATH)
raw_df.head()

# %%
quality = data_quality_report(raw_df)
quality["shape"], quality.get("target_distribution")

# %%
pd.DataFrame({"dtype": raw_df.dtypes.astype(str), "missing": raw_df.isna().sum()})
