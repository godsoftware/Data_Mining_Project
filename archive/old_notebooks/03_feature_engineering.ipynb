# %% [markdown]
# # 03 Feature Engineering
#
# Goal: create payment-behavior, bill, payment, ratio, and utilization proxy features.

# %%
from pathlib import Path
import sys
import pandas as pd

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.append(str(PROJECT_ROOT / "src"))

from data_preprocessing import INTERIM_DATA_PATH
from feature_engineering import make_model_ready_dataset, PROCESSED_DATA_PATH

# %%
clean_df = pd.read_csv(INTERIM_DATA_PATH)
model_ready = make_model_ready_dataset(clean_df)
model_ready.to_csv(PROCESSED_DATA_PATH, index=False)
model_ready.head()

# %%
engineered_features = [
    "delay_count",
    "max_delay",
    "avg_delay",
    "recent_delay",
    "severe_delay_count",
    "total_bill_amt",
    "avg_bill_amt",
    "max_bill_amt",
    "bill_trend",
    "total_pay_amt",
    "avg_pay_amt",
    "max_pay_amt",
    "payment_to_bill_ratio",
    "utilization_proxy",
]
model_ready[engineered_features].describe().T
